# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv(r"C:\Proyectos\Salle\SeminarioDataScience\archivos_base_python_data_science_big_data_esencial\base_datos_2008.csv\base_datos_2008.csv", nrows=1000)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.tail()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 995  2008      1           3          4   2154.0        2040   2314.0
# 996  2008      1           3          4   1322.0        1245   1444.0
# 997  2008      1           3          4    701.0         700    823.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 999  2008      1           3          4    834.0         830    955.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 995        2205            WN        428  ...    4.0     13.0          0
# 996        1410            WN        500  ...    3.0     15.0          0
# 997         825            WN        565  ...    4.0     17.0          0
# 998        1135            WN        752  ...    5.0     11.0          0
# 999         955            WN        762  ...    4.0     18.0          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# DayofMonth             0
# DayOfWeek              0
# DepTime               12
# CRSDepTime             0
# ArrTime               12
# CRSArrTime             0
# UniqueCarrier          0
# FlightNum              0
# TailNum               12
# ActualElapsedTime     12
# CRSElapsedTime         0
# AirTime               12
# ArrDelay              12
# DepDelay              12
# Origin                 0
# Dest                   0
# Distance               0
# TaxiIn                12
# TaxiOut               12
# Cancelled              0
# CancellationCode     988
# Diverted               0
# CarrierDelay         490
# WeatherDelay         490
# NASDelay             490
# SecurityDelay        490
# LateAircraftDelay    490
# dtype: int64

# %%
dfok = df["ArrDelay"].dropna()
dfok.head()
# Out:
# 0   -14.0
# 1     2.0
# 2    14.0
# 3    -6.0
# 4    34.0
# Name: ArrDelay, dtype: float64

# %%
df
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0    2008      1           3          4   2003.0        1955   2211.0
# 1    2008      1           3          4    754.0         735   1002.0
# 2    2008      1           3          4    628.0         620    804.0
# 3    2008      1           3          4    926.0         930   1054.0
# 4    2008      1           3          4   1829.0        1755   1959.0
# ..    ...    ...         ...        ...      ...         ...      ...
# 995  2008      1           3          4   2154.0        2040   2314.0
# 996  2008      1           3          4   1322.0        1245   1444.0
# 997  2008      1           3          4    701.0         700    823.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 999  2008      1           3          4    834.0         830    955.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.tail()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 995  2008      1           3          4   2154.0        2040   2314.0
# 996  2008      1           3          4   1322.0        1245   1444.0
# 997  2008      1           3          4    701.0         700    823.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 999  2008      1           3          4    834.0         830    955.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 995        2205            WN        428  ...    4.0     13.0          0
# 996        1410            WN        500  ...    3.0     15.0          0
# 997         825            WN        565  ...    4.0     17.0          0
# 998        1135            WN        752  ...    5.0     11.0          0
# 999         955            WN        762  ...    4.0     18.0          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# ...

# %%
df.sample(frac = 1)
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 320  2008      1           3          4   1735.0        1710   2010.0
# 835  2008      1           3          4   1542.0        1515   1805.0
# 435  2008      1           3          4   1725.0        1655   2238.0
# 597  2008      1           3          4    622.0         615    750.0
# 692  2008      1           3          4   2334.0        1950    157.0
# ..    ...    ...         ...        ...      ...         ...      ...
# 99   2008      1           3          4   1824.0        1715    117.0
# 674  2008      1           3          4   2033.0        1905   2249.0
# 329  2008      1           3          4   1925.0        1735   2201.0
# 509  2008      1           3          4    645.0         635    822.0
# 891  2008      1           3          4    634.0         620    952.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.sample(frac = 1,random_state=1)
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 507  2008      1           3          4   2016.0        2020   2141.0
# 818  2008      1           3          4    633.0         630    934.0
# 452  2008      1           3          4   2007.0        2010   2102.0
# 368  2008      1           3          4   1827.0        1800   1945.0
# 242  2008      1           3          4   2137.0        2040   2251.0
# ..    ...    ...         ...        ...      ...         ...      ...
# 767  2008      1           3          4   1508.0        1430   1700.0
# 72   2008      1           3          4   1820.0        1825   1946.0
# 908  2008      1           3          4   1206.0        1135   1511.0
# 235  2008      1           3          4   1716.0        1630   1830.0
# 37   2008      1           3          4   1812.0        1650   1927.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df = df.sample(frac = 1)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.Origin
# Out:
# 14     IND
# 425    LAX
# 325    LAX
# 838    MDW
# 417    LAX
#       ...
# 624    MCO
# 132    LAS
# 809    MDW
# 753    MDW
# 932    MSY
# Name: Origin, Length: 1000, dtype: object

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values
# Out:
# array([[2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 3, ..., nan, nan, nan],
#        ...,
#        [2008, 1, 3, ..., 0.0, 0.0, 0.0],
#        [2008, 1, 3, ..., 0.0, 0.0, 27.0],
#        [2008, 1, 3, ..., 0.0, 0.0, 30.0]], dtype=object)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df["FlightNum"].head()
# Out:
# 984    3772
# 998     752
# 358    1930
# 834    1414
# 181     237
# Name: FlightNum, dtype: int64

# %%
df[0:10]
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 984  2008      1           3          4    817.0         805    919.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 358  2008      1           3          4    630.0         625   1209.0
# 834  2008      1           3          4    750.0         730   1002.0
# 181  2008      1           3          4   1251.0        1205   1425.0
# 421  2008      1           3          4   1114.0        1045   1347.0
# 762  2008      1           3          4    650.0         615    840.0
# 129  2008      1           3          4   1725.0        1620   1940.0
# 431  2008      1           3          4   1524.0        1505   1634.0
# 773  2008      1           3          4   1414.0        1400   1641.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 984         910            WN       3772  ...    2.0     11.0          0
# ...

# %%
df["ArrDelay"]
# Out:
# 984     9.0
# 998     1.0
# 358   -11.0
# 834    12.0
# 181    40.0
#        ...
# 248    20.0
# 445     0.0
# 869    39.0
# 443    31.0
# 91     49.0
# Name: ArrDelay, Length: 1000, dtype: float64

# %%
df[df["ArrDelay"] < 60].head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 984  2008      1           3          4    817.0         805    919.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 358  2008      1           3          4    630.0         625   1209.0
# 834  2008      1           3          4    750.0         730   1002.0
# 181  2008      1           3          4   1251.0        1205   1425.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 984         910            WN       3772  ...    2.0     11.0          0
# 998        1135            WN        752  ...    5.0     11.0          0
# 358        1220            WN       1930  ...    4.0      9.0          0
# 834         950            WN       1414  ...    6.0      7.0          0
# 181        1345            WN        237  ...    3.0     15.0          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[df["ArrDelay"] !=  60].head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 984  2008      1           3          4    817.0         805    919.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 358  2008      1           3          4    630.0         625   1209.0
# 834  2008      1           3          4    750.0         730   1002.0
# 181  2008      1           3          4   1251.0        1205   1425.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 984         910            WN       3772  ...    2.0     11.0          0
# 998        1135            WN        752  ...    5.0     11.0          0
# 358        1220            WN       1930  ...    4.0      9.0          0
# 834         950            WN       1414  ...    6.0      7.0          0
# 181        1345            WN        237  ...    3.0     15.0          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[df["Origin"] == "LAX"].head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 358  2008      1           3          4    630.0         625   1209.0
# 421  2008      1           3          4   1114.0        1045   1347.0
# 431  2008      1           3          4   1524.0        1505   1634.0
# 427  2008      1           3          4   2013.0        1910   2121.0
# 344  2008      1           3          4    744.0         740    838.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 358        1220            WN       1930  ...    4.0      9.0          0
# 421        1330            WN        963  ...    3.0     10.0          0
# 431        1620            WN       2720  ...    4.0      7.0          0
# 427        2025            WN       1015  ...    3.0      7.0          0
# 344         840            WN       2111  ...    3.0      5.0          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df [   (  df["ArrDelay"] == 60 ) | ( df ["Origin"] == "LAX"  )    ].head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 358  2008      1           3          4    630.0         625   1209.0
# 421  2008      1           3          4   1114.0        1045   1347.0
# 431  2008      1           3          4   1524.0        1505   1634.0
# 427  2008      1           3          4   2013.0        1910   2121.0
# 344  2008      1           3          4    744.0         740    838.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 358        1220            WN       1930  ...    4.0      9.0          0
# 421        1330            WN        963  ...    3.0     10.0          0
# 431        1620            WN       2720  ...    4.0      7.0          0
# 427        2025            WN       1015  ...    3.0      7.0          0
# 344         840            WN       2111  ...    3.0      5.0          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[df.Origin.isin(["LAX","HOU"])].head()  # in
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 358  2008      1           3          4    630.0         625   1209.0
# 421  2008      1           3          4   1114.0        1045   1347.0
# 431  2008      1           3          4   1524.0        1505   1634.0
# 427  2008      1           3          4   2013.0        1910   2121.0
# 344  2008      1           3          4    744.0         740    838.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 358        1220            WN       1930  ...    4.0      9.0          0
# 421        1330            WN        963  ...    3.0     10.0          0
# 431        1620            WN       2720  ...    4.0      7.0          0
# 427        2025            WN       1015  ...    3.0      7.0          0
# 344         840            WN       2111  ...    3.0      5.0          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[pd.isna(df["ArrDelay"])].head(20)
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 676  2008      1           3          4      NaN         845      NaN
# 884  2008      1           3          4      NaN        1445      NaN
# 727  2008      1           3          4      NaN         600      NaN
# 399  2008      1           3          4      NaN         905      NaN
# 178  2008      1           3          4      NaN         700      NaN
# 881  2008      1           3          4      NaN        1110      NaN
# 977  2008      1           3          4      NaN        1310      NaN
# 415  2008      1           3          4      NaN        1930      NaN
# 686  2008      1           3          4      NaN        1925      NaN
# 401  2008      1           3          4      NaN        1620      NaN
# 974  2008      1           3          4      NaN        1705      NaN
# 373  2008      1           3          4      NaN        1100      NaN
#
# ...

# %%
len(df[pd.isna(df["ArrDelay"])])
# Out:
# 12

# %%
len(df.columns)
# Out:
# 29

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df["Horas"] = round(df["ArrDelay"] / 60)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay',
#        'Horas'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 30

# %%
df["Horas"].head()
# Out:
# 984    0.0
# 998    0.0
# 358   -0.0
# 834    0.0
# 181    1.0
# Name: Horas, dtype: float64

# %%
df.head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 984  2008      1           3          4    817.0         805    919.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 358  2008      1           3          4    630.0         625   1209.0
# 834  2008      1           3          4    750.0         730   1002.0
# 181  2008      1           3          4   1251.0        1205   1425.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 984         910            WN       3772  ...    11.0          0
# 998        1135            WN        752  ...    11.0          0
# 358        1220            WN       1930  ...     9.0          0
# 834         950            WN       1414  ...     7.0          0
# 181        1345            WN        237  ...    15.0          0
#
#      CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 984               NaN         0           NaN           NaN      NaN
# ...

# %%
df.head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 984  2008      1           3          4    817.0         805    919.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 358  2008      1           3          4    630.0         625   1209.0
# 834  2008      1           3          4    750.0         730   1002.0
# 181  2008      1           3          4   1251.0        1205   1425.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 984         910            WN       3772  ...    11.0          0
# 998        1135            WN        752  ...    11.0          0
# 358        1220            WN       1930  ...     9.0          0
# 834         950            WN       1414  ...     7.0          0
# 181        1345            WN        237  ...    15.0          0
#
#      CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 984               NaN         0           NaN           NaN      NaN
# ...

# %%
df.drop(["Diverted","Cancelled","Year"], axis=1)
# Out:
#      Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 984      1           3          4    817.0         805    919.0         910
# 998      1           3          4   1012.0        1010   1136.0        1135
# 358      1           3          4    630.0         625   1209.0        1220
# 834      1           3          4    750.0         730   1002.0         950
# 181      1           3          4   1251.0        1205   1425.0        1345
# ..     ...         ...        ...      ...         ...      ...         ...
# 248      1           3          4   1348.0        1330   1455.0        1435
# 445      1           3          4    840.0         840    940.0         940
# 869      1           3          4    824.0         735   1059.0        1020
# 443      1           3          4   1825.0        1745   1921.0        1850
# 91       1           3          4   1739.0        1640    114.0          25
#
# ...

# %%
df.drop(["Diverted","Cancelled","Year"], axis=1, inplace=True)

# %%
df.head()
# Out:
#      Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 984      1           3          4    817.0         805    919.0         910
# 998      1           3          4   1012.0        1010   1136.0        1135
# 358      1           3          4    630.0         625   1209.0        1220
# 834      1           3          4    750.0         730   1002.0         950
# 181      1           3          4   1251.0        1205   1425.0        1345
#
#     UniqueCarrier  FlightNum TailNum  ...  Distance  TaxiIn  TaxiOut  \
# 984            WN       3772  N708SA  ...       325     2.0     11.0
# 998            WN        752  N680AA  ...       407     5.0     11.0
# 358            WN       1930  N724SW  ...      1750     4.0      9.0
# 834            WN       1414  N402WN  ...       402     6.0      7.0
# 181            WN        237  N281WN  ...       407     3.0     15.0
#
#      CancellationCode  CarrierDelay WeatherDelay NASDelay  SecurityDelay  \
# ...

# %%
len(df)
# Out:
# 1000

# %%
df.drop(515)
# Out:
#      Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 984      1           3          4    817.0         805    919.0         910
# 998      1           3          4   1012.0        1010   1136.0        1135
# 358      1           3          4    630.0         625   1209.0        1220
# 834      1           3          4    750.0         730   1002.0         950
# 181      1           3          4   1251.0        1205   1425.0        1345
# ..     ...         ...        ...      ...         ...      ...         ...
# 248      1           3          4   1348.0        1330   1455.0        1435
# 445      1           3          4    840.0         840    940.0         940
# 869      1           3          4    824.0         735   1059.0        1020
# 443      1           3          4   1825.0        1745   1921.0        1850
# 91       1           3          4   1739.0        1640    114.0          25
#
# ...

# %%
dfLAX = df[df.Origin == "LAX"]
dfOAK = df[df.Origin == "OAK"]

# %%
dfLAX = df[df.Origin == "LAX"]

# %%
dfOAK = df[df.Origin == "OAK"]

# %%
print(len(dfOAK), " ", len(dfLAX))
# Out:
# 38   122

# %%
df.drop(range(0,100))
# Out:
#      Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 984      1           3          4    817.0         805    919.0         910
# 998      1           3          4   1012.0        1010   1136.0        1135
# 358      1           3          4    630.0         625   1209.0        1220
# 834      1           3          4    750.0         730   1002.0         950
# 181      1           3          4   1251.0        1205   1425.0        1345
# ..     ...         ...        ...      ...         ...      ...         ...
# 253      1           3          4    946.0         940   1045.0        1045
# 248      1           3          4   1348.0        1330   1455.0        1435
# 445      1           3          4    840.0         840    940.0         940
# 869      1           3          4    824.0         735   1059.0        1020
# 443      1           3          4   1825.0        1745   1921.0        1850
#
# ...

# %%
dfLAX.append(dfOAK)
# Out:
#      Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 358      1           3          4    630.0         625   1209.0        1220
# 421      1           3          4   1114.0        1045   1347.0        1330
# 431      1           3          4   1524.0        1505   1634.0        1620
# 427      1           3          4   2013.0        1910   2121.0        2025
# 344      1           3          4    744.0         740    838.0         840
# ..     ...         ...        ...      ...         ...      ...         ...
# 974      1           3          4      NaN        1705      NaN        1810
# 980      1           3          4   1243.0        1220   1345.0        1325
# 972      1           3          4   2051.0        2015   2151.0        2120
# 992      1           3          4   1620.0        1520   2144.0        2100
# 967      1           3          4   1953.0        1935   2218.0        2200
#
# ...

# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv(r"C:\Proyectos\Salle\SeminarioDataScience\archivos_base_python_data_science_big_data_esencial\base_datos_2008.csv\base_datos_2008.csv")

# %%
len(df)
# Out:
# 7009728

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.groupby(by="DayOfWeek")   ["ArrDelay"].max()
# Out:
# DayOfWeek
# 1    1583.0
# 2    1951.0
# 3    1510.0
# 4    2453.0
# 5    1707.0
# 6    1525.0
# 7    2461.0
# Name: ArrDelay, dtype: float64

# %%
agrupa = df.groupby(by="DayOfWeek")["ArrDelay"].min()
agrupa

agrupa["max"] = df.groupby(by="DayOfWeek")["ArrDelay"].max()
agrupa.head()
# Out:
# DayOfWeek
# 1   -519.0
# 2    -89.0
# 3    -87.0
# 4   -129.0
# 5    -86.0
# Name: ArrDelay, dtype: object

# %%
agrupa
# Out:
# DayOfWeek
# 1                                                 -519.0
# 2                                                  -89.0
# 3                                                  -87.0
# 4                                                 -129.0
# 5                                                  -86.0
# 6                                                  -91.0
# 7                                                  -92.0
# max    DayOfWeek
# 1    1583.0
# 2    1951.0
# 3    1510.0
# ...
# Name: ArrDelay, dtype: object

# %%
type(agrupa)
# Out:
# pandas.core.series.Series

# %%
agrupa = df.groupby(by="DayOfWeek")["ArrDelay"].min()
agrupa.head()
type(agrupa)
# Out:
# pandas.core.series.Series

# %%
agrupa.head()
# Out:
# DayOfWeek
# 1   -519.0
# 2    -89.0
# 3    -87.0
# 4   -129.0
# 5    -86.0
# Name: ArrDelay, dtype: float64

# %%
df2 = pd.DataFrame(agrupa)
df2.rename(columns={"ArrDelay":"RetrasoMinimo"}, inplace=True)

# %%
df2
# Out:
#            RetrasoMinimo
# DayOfWeek
# 1                 -519.0
# 2                  -89.0
# 3                  -87.0
# 4                 -129.0
# 5                  -86.0
# 6                  -91.0
# 7                  -92.0

# %%
agrupa = df.groupby(by="DayOfWeek")["ArrDelay"].max()
df2["RetrasoMax"] = agrupa
df2
# Out:
#            RetrasoMinimo  RetrasoMax
# DayOfWeek
# 1                 -519.0      1583.0
# 2                  -89.0      1951.0
# 3                  -87.0      1510.0
# 4                 -129.0      2453.0
# 5                  -86.0      1707.0
# 6                  -91.0      1525.0
# 7                  -92.0      2461.0

# %%
agrupa = df.groupby(by="DayOfWeek")["ArrDelay"].mean()
df2["RetrasoPromedio"] = agrupa
df2
# Out:
#            RetrasoMinimo  RetrasoMax  RetrasoPromedio
# DayOfWeek
# 1                 -519.0      1583.0         8.210850
# 2                  -89.0      1951.0         7.481208
# 3                  -87.0      1510.0         6.522017
# 4                 -129.0      2453.0         8.411599
# 5                  -86.0      1707.0        10.953440
# 6                  -91.0      1525.0         5.789666
# 7                  -92.0      2461.0         9.495886

# %%
df.groupby(by="DayOfWeek")["ArrDelay"].describe()
# Out:
#                count       mean        std    min   25%  50%   75%     max
# DayOfWeek
# 1          1013410.0   8.210850  38.013811 -519.0 -10.0 -2.0  12.0  1583.0
# 2          1005992.0   7.481208  38.361073  -89.0 -11.0 -3.0  11.0  1951.0
# 3          1016995.0   6.522017  36.024679  -87.0 -10.0 -3.0  10.0  1510.0
# 4          1011970.0   8.411599  37.397411 -129.0 -10.0 -1.0  12.0  2453.0
# 5          1008872.0  10.953440  40.252320  -86.0  -9.0  0.0  15.0  1707.0
# 6           841663.0   5.789666  37.163120  -91.0 -11.0 -3.0   9.0  1525.0
# 7           956127.0   9.495886  41.759296  -92.0 -10.0 -2.0  12.0  2461.0

# %%
df.groupby(by="DayOfWeek")[["ArrDelay","DepDelay"]].max()
# Out:
# C:\Users\Jsilva\AppData\Local\Temp/ipykernel_31624/3499575819.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by="DayOfWeek")["ArrDelay","DepDelay"].max()
#            ArrDelay  DepDelay
# DayOfWeek
# 1            1583.0    1552.0
# 2            1951.0    1952.0
# 3            1510.0    1518.0
# 4            2453.0    2467.0
# 5            1707.0    1710.0
# 6            1525.0    1521.0
# 7            2461.0    2457.0

# %%
df.groupby(by="DayOfWeek")["ArrDelay"].max() - df.groupby(by="DayOfWeek")["ArrDelay"].min()
# Out:
# DayOfWeek
# 1    2102.0
# 2    2040.0
# 3    1597.0
# 4    2582.0
# 5    1793.0
# 6    1616.0
# 7    2553.0
# Name: ArrDelay, dtype: float64

# %%
pd.DataFrame((df.groupby(by="DayOfWeek")["ArrDelay"].max() - df.groupby(by="DayOfWeek")["ArrDelay"].min())).rename(columns={"ArrDelay":"RangoRetrasos"}).sort_values(["RangoRetrasos"],ascending=[False])
# Out:
#            RangoRetrasos
# DayOfWeek
# 4                 2582.0
# 7                 2553.0
# 1                 2102.0
# 2                 2040.0
# 5                 1793.0
# 6                 1616.0
# 3                 1597.0

# %%
df[df.Origin.isin(["LAX","HOU"])].groupby(by=["DayOfWeek","Origin"])["ArrDelay"].mean()
# Out:
# DayOfWeek  Origin
# 1          HOU        6.356856
#            LAX        5.143895
# 2          HOU        9.348112
#            LAX        2.912576
# 3          HOU        9.073109
#            LAX        3.583050
# 4          HOU       12.994016
#            LAX        5.620814
# 5          HOU       11.036545
#            LAX        7.368246
# 6          HOU        4.283933
#            LAX        3.710689
# 7          HOU        7.045287
#            LAX        8.348621
# Name: ArrDelay, dtype: float64

# %%
agrupacion = df[df.Origin.isin(["LAX","HOU"])].groupby(by=["DayOfWeek","Origin"])["ArrDelay"]

# %%
agrupacion.mean()
# Out:
# DayOfWeek  Origin
# 1          HOU        6.356856
#            LAX        5.143895
# 2          HOU        9.348112
#            LAX        2.912576
# 3          HOU        9.073109
#            LAX        3.583050
# 4          HOU       12.994016
#            LAX        5.620814
# 5          HOU       11.036545
#            LAX        7.368246
# 6          HOU        4.283933
#            LAX        3.710689
# 7          HOU        7.045287
#            LAX        8.348621
# Name: ArrDelay, dtype: float64

# %%
len(df)
# Out:
# 7009728

# %%
import pandas as pd
df = pd.read_csv(r"C:\Proyectos\Salle\SeminarioDataScience\archivos_base_python_data_science_big_data_esencial\base_datos_2008.csv\base_datos_2008.csv")

# %%
len(df)
# Out:
# 7009728

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
## 
df2 = df.drop_duplicates()

# %%
len(df2)
# Out:
# 7009724

# %%
df.drop_duplicates(subset="FlightNum")
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4   2003.0        1955   2211.0
# 1        2008      1           3          4    754.0         735   1002.0
# 2        2008      1           3          4    628.0         620    804.0
# 3        2008      1           3          4    926.0         930   1054.0
# 4        2008      1           3          4   1829.0        1755   1959.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 6119438  2008     11          27          4   1551.0        1553   1759.0
# 6609041  2008     12          14          7   1625.0        1600   1725.0
# 6609916  2008     12          16          2   1131.0        1131   1226.0
# 6611861  2008     12          20          6    640.0         630    810.0
# 6616659  2008     12          31          3   1710.0        1640   1905.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
dforiginunico
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4   2003.0        1955   2211.0
# 2        2008      1           3          4    628.0         620    804.0
# 19       2008      1           3          4   1416.0        1325   1512.0
# 47       2008      1           3          4    831.0         830   1148.0
# 56       2008      1           3          4    948.0         925    959.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 3790987  2008      7           7          1      NaN        1750      NaN
# 3791022  2008      7           7          1   1727.0        1736   1916.0
# 4694489  2008      8          20          3    600.0         600    738.0
# 5524646  2008     10           1          3   1130.0        1140   1211.0
# 6348854  2008     11           9          7    809.0         800    922.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
dfok = df.dropna(subset=["ArrDelay"])

# %%
len(dfok)
# Out:
# 6855029

# %%
7009724 - 6855029
# Out:
# 154695

# %%
df[df.ArrDelay.isnull()]
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178      2008      1           3          4      NaN         700      NaN
# 373      2008      1           3          4      NaN        1100      NaN
# 399      2008      1           3          4      NaN         905      NaN
# 401      2008      1           3          4      NaN        1620      NaN
# 415      2008      1           3          4      NaN        1930      NaN
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009455  2008     12          13          6      NaN         600      NaN
# 7009464  2008     12          13          6      NaN        1930      NaN
# 7009564  2008     12          13          6      NaN         700      NaN
# 7009565  2008     12          13          6      NaN        1115      NaN
# 7009648  2008     12          13          6      NaN        1020      NaN
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.loc[df.ArrDelay.isnull(),"ArrDelay"] = -1

# %%
df = pd.DataFrame([['No1',2], [4,5], [7,8],['7,000','8,000']], 
                  index=['cobra', 'viper', 'sidewinder','comasnumero'], 
                  columns=['max_speed', 'shield'])

# %%
type(df)
df.columns
df.dtypes
# Out:
# max_speed    object
# shield       object
# dtype: object

# %%
df.head()
# Out:
#             max_speed shield
# cobra             No1      2
# viper               4      5
# sidewinder          7      8
# comasnumero     7,000  8,000

# %%
df["max_speed"] = df["max_speed"].astype(str)
df["shield"] = df["shield"].astype(str)
df["max_speedb"] = df["max_speed"].str.isnumeric()
df["shieldb"] = df["shield"].str.isnumeric()
df
# Out:
#             max_speed shield  max_speedb  shieldb
# cobra             No1      2       False     True
# viper               4      5        True     True
# sidewinder          7      8        True     True
# comasnumero     7,000  8,000       False    False

# %%
df[df["max_speedb"]== False]
# Out:
#             max_speed shield  max_speedb  shieldb
# cobra             No1      2       False     True
# comasnumero     7,000  8,000       False    False

# %%
df.loc[df["max_speedb"]== False,"max_speed"] = df["max_speed"].str.replace(",", "")

# %%
df
# Out:
#             max_speed shield  max_speedb  shieldb
# cobra             No1      2       False     True
# viper               4      5        True     True
# sidewinder          7      8        True     True
# comasnumero      7000  8,000       False    False

# %%
df["max_speedb"] = df["max_speed"].str.isnumeric()
df
# Out:
#             max_speed shield max_speedb  shieldb
# cobra               0      2        NaN     True
# viper               4      5       True     True
# sidewinder          7      8       True     True
# comasnumero      7000  8,000       True    False

# %%
df.loc[df["max_speedb"]== False,"max_speed"] = 0
df
# Out:
#             max_speed shield  max_speedb  shieldb
# cobra               0      2       False     True
# viper               4      5        True     True
# sidewinder          7      8        True     True
# comasnumero      7000  8,000        True    False

# %%
df.dtypes
# Out:
# max_speed     object
# shield        object
# max_speedb      bool
# shieldb         bool
# dtype: object

# %%
df["max_speedb"] = df["max_speed"].str.isnumeric()
df

# %%
df["max_speed"] = df["max_speed"].astype(int)
df
# Out:
#              max_speed shield max_speedb  shieldb
# cobra                0      2        NaN     True
# viper                4      5       True     True
# sidewinder           7      8       True     True
# comasnumero       7000  8,000       True    False

# %%
df.dtypes
# Out:
# max_speed      int32
# shield        object
# max_speedb    object
# shieldb         bool
# dtype: object

# %%
df.loc[df["shieldb"]== False,"shield"] = df["shield"].str.replace(",", "")
